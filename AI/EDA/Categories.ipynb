# %% [markdown]
# ## Getting categories with codes out of dataset

# %%
# Imports 
import pandas as pd
import json
import re

# Read the Excel file
df = pd.read_excel('RESOURCES.xlsx')

def clean_category2(category):
    if pd.isna(category):
        return category
    # Remove first number group (e.g., "01 06 Logistics" -> "06 Logistics")
    return re.sub(r'^\d+\s+', '', category)

def clean_category3(category):
    if not isinstance(category, str):
        return category
        
    # Split the string into parts
    parts = category.split()
    
    # Find the last number-text pair
    number = None
    text = []
    
    for i in range(len(parts)-1, -1, -1):
        if re.match(r'^\d+$', parts[i]) and not number:
            number = parts[i]
            break
        text.insert(0, parts[i])
    
    # If no number found, try to extract from beginning
    if not number and text:
        match = re.match(r'^(\d+)\s*(.*)', text[0])
        if match:
            number = match.group(1)
            text[0] = match.group(2)
    
    # Combine number and text
    if number and text:
        return f"{number} {' '.join(text)}"
    return category

# Clean categories
df['Category 2'] = df['Category 2'].apply(clean_category2)
df['Category 3'] = df['Category 3'].apply(clean_category3)

# Extract unique values from Category1, Category2, and Category3 columns
unique_category1 = df['Category 1'].dropna().unique().tolist()
unique_category2 = df['Category 2'].dropna().unique().tolist()
unique_category3 = df['Category 3'].dropna().unique().tolist()

# Create a dictionary to hold the unique categories
unique_categories = {
    "Category1": unique_category1,
    "Category2": unique_category2,
    "Category3": unique_category3
}

# Save to JSON file
with open('unique_categories_final.json', 'w') as json_file:
    json.dump(unique_categories, json_file, indent=4)

print("Unique categories have been saved to unique_categories.json")
# Out:
# Unique categories have been saved to unique_categories.json

# %%
# What unique values are in the categories columns
data = pd.read_excel('RESOURCES.xlsx')
print(data['Category 1'].nunique() + data['Category 2'].nunique() + data['Category 3'].nunique())
# Out:
# 376

# %%
print(data['Category 2'].unique())
# Out:
# ['01 06 Logistics' '06 03 Compost, Peat Etc' '01 10 Equipment'
#  '01 04 Manufacturing / Processing' '06 05 Green Waste'
#  '06 02 Arable Produce & Wastes (Non-Fuel)' '04 02 Heat' '20 05 Other'
#  '16 02 Batteries' '12 19 Solvents' '03 04 Paints & Varnishes'
#  '19 04 Plastic (Unspecified)' '01 11 Labour'
#  '06 06 Other Food & Beverage Wastes' '06 07 Prepared Food Waste'
#  '12 18 Soaps, Detergents, Oils, Waxes, Etc' '20 14 Polyurethane PU PUR'
#  '99 99 Unspecified' '22 02 Product' '22 03 Processed Wood' ' '
#  '20 99 Unspecified' '15 05 Wastewater' '01 09 Waste Handling Facilities'
#  '22 01 Production' '12 01 Alcohols, Glycols, Glycerol '
#  '07 07 Calcium Compounds (See Also Alkalis)' '07 02 Alkalies'
#  '12 11 Organic Acids, Salts & Anhydrides ' '10 03 Pure Metals'
#  '07 03 Aluminum Compounds' '21 04 Tyres' '10 01 Alloys, Including Steel'
#  '07 18 Nitrogen Compounds, Ammonium Salts' '01 03 Laboratories'
#  '14 02 Leather' '01 08 Storage' '07 99 Unspecified' '01 07 Office Space'
#  '11 01 Ceramics, Refractories, Ashphalts Etc' '11 99 Unspecified'
#  '11 05 Construction Waste Not covered elsewhere' '22 99 Unspecified'
#  '19 99 Unspecified' '12 99 Unspecified' '05 99 Unspecified'
#  '04 03 Non-Renewablel Fuel' '04 04 Renewable Fuel' '19 05 Other'
#  '12 07 Hydrocarbons Not Treated As Solvents Or Fuel'
#  '11 04 Slag & Ash ( Non Metal Rich)' '08 01 Specified Use'
#  '11 03 Minerals, Rock & Stone' '12 09 Miscellaneous Chemical Products'
#  '04 99 Unspecified' '08 02 Unspecified Use' '09 01 Commercial'
#  '01 99 Unspecified' '05 12 Research, Development, Design' '07 12 Gases'
#  '05 08 Marketing, Communication' '05 04 Infrastructure, Environment'
#  '14 03 Textiles - Fabrics' '12 05 Esters, Including Fats, Plasticisers'
#  '15 99 Unspecified' '09 02 Unused' '04 01 Electricity'
#  '10 02 Metal-rich Materials' '05 10 Production, Technology, Engineering'
#  '16 99 Unspecified' '05 13 Sciences' '18 02 Consumer glass'
#  '18 99 Unspecified' '10 99 Unspecified' '05 06 Law, Legal Matters'
#  '20 10 Polyethylene Polythene' '06 99 Unspecified'
#  '12 15 Other Organics With Known Chemical Composition'
#  '18 01 Mineral glass' '19 03 Paper & Cardboard' '22 05 Paper'
#  '06 04 Fats & Oils' '08 99 Unspecified'
#  '20 15 Polyvinyl Chloride/ PVC/uPVC/Vinyl'
#  '20 02 High Density Polyethylene HDPE' '17 10 Vehicle'
#  '17 08 Other Machinery, Appliances and Equipment' '03 99 Unspecified'
#  '05 11 Quality, Efficiency, Outsourcing' '05 07 Logistics' '05 05 IT'
#  '05 02 Construction, Real Estate'
#  '16 04 Electrical/Electronic Tools (Not Incl large-scale stationary indus tools)'
#  '01 02 Engineering Workshop Facilities' '15 01 Clean Water'
#  '20 12 Polypropylene PP' '20 06 Other Polyester'
#  '20 03 Low Density Polyethylene LDPE' '09 99 Unspecified'
#  '06 01 Animal Products' '14 99 Unspecified' '20 04 Nylon'
#  '20 08 Polyethylene terephthalate PET' '20 13 Polystyrene PS'
#  '20 01 Acetal POM Polyoxymethylene ' '20 09 Polycarbonate'
#  '15 02 Drainage Water' '14 01 Fur' '21 02 Other Rubber'
#  '07 14 Inorganics Without Specific Chemical Composition'
#  '07 23 Silicon Compounds ' '15 03 Sludge ' '07 20 Phosphorus Compounds'
#  '14 04 Textiles - Other' '05 09 Personnel, Training, Coaching'
#  '01 05 Meetings and Conference'
#  '03 01 Albuminoidal Subst/Starches/Glues/Enzymes'
#  '07 24 Sodium Compounds ']

# %%
print(data['Category 3'].unique(), data['Category 3'].nunique())
# Out:
# ['01 06 02 Road Transport' '06 03 04 Topsoil' '01 10 02 To Use On - Site'
#  '01 04 02 Manufacturing' '06 05 01 Fruit/Vegetable Waste - Compostable'
#  '06 02 02 Other' '06 02 99 Unspecified' '04 02 01 Hot water'
#  '20 05 01 Other' '16 02 04 Other Batteries' '12 19 01 Acetone'
#  '03 04 01 Other Paints & Varnishes (incl. Enamels)'
#  '19 04 01 Plastic (Unspecified)' '01 11 01 Manpower'
#  '06 06 03 Other Food Sludges & Wastes' '04 02 02 Other'
#  '06 07 02 Not Containing Animal Products'
#  '12 18 02 Lubricating Preparations, & Other Oils Etc'
#  '20 14 01 Polyurethane PU PUR' '99 99 99 Unspecified' '22 02 03 Off cuts'
#  '22 03 99 Unspecified' ' ' '20 99 99 Unspecified'
#  '15 05 05 Industrial Process Plant Water' '15 05 99 Unspecified'
#  '01 09 03 Other' '22 01 99 Unspecified' '12 01 99 Unspecified'
#  '07 07 99 Unspecified' '07 02 03 Other Alkalis' '12 11 07 Lactic Acid'
#  '04 02 99 Unspecified' '10 03 23 Aluminium'
#  '07 03 03 Other Aluminium Compounds' '10 03 10 Other' '21 04 01 Tyres'
#  '10 01 01 Aluminium Alloys' '07 18 01 Ammonium Salts'
#  '01 03 01 Analytical' '14 02 01 Other Leather Items'
#  '12 11 01 Acetic Acid' '01 08 99 Unspecified' '07 99 99 Unspecified'
#  '01 07 02 Room Only' '01 07 03 Serviced' '22 03 04 Other'
#  '11 01 04 Concrete & Artificial Stone' '11 99 99 Unspecified'
#  '11 05 01 Other' '11 01 02 Bricks, Blocks, Tiles' '22 99 99 Unspecified'
#  '19 99 99 Unspecified' '12 99 99 Unspecified' '05 99 99 Unspecified'
#  '04 03 01 Charcoal' '04 04 03 Biogas' '19 05 01 Other'
#  '06 05 05 Other Green Waste' '04 04 07 Other Biomass' '12 07 02 Bitumen'
#  '10 01 10 Other' '11 04 01 Ash & Residues' '06 02 05 Straw'
#  '11 05 99 Unspecified' '08 01 03 Industrial Land'
#  '11 03 20 Sand, (excl. Metal-bearing Sands)'
#  '12 09 12 Refractory Cements, Mortars, Concretes & Similar Compositions, n.e.s'
#  '08 01 01 Agricultural land' '04 99 99 Unspecified'
#  '08 02 01 Brownfield Sites' '09 01 03 Inland Shipping'
#  '01 99 99 Unspecified' '01 03 03 Materials Testing'
#  '01 10 99 Unspecified' '01 03 04 Other' '01 09 99 Unspecified'
#  '05 12 08 Research & Innovation Management' '07 12 02 Carbon Dioxide'
#  '05 08 99 Unspecified' '06 03 02 Compost' '06 03 99 Unspecified'
#  '09 01 02 Containers' '05 04 01 ISO 14001' '01 08 03 Tankage'
#  '14 03 07 Other Artificial Fibres' '01 08 04 Warehouse'
#  '06 06 99 Unspecified' '06 07 01 Containing Animal Products'
#  '12 05 01 Biodiesel & Related Products (Fatty Acid Methyl Esters)'
#  '15 99 99 Unspecified' '04 02 03 Steam' '07 12 99 Unspecified'
#  '09 01 06 Road Transport, Traffic'
#  '11 03 08 Granite, Porphyry, Etc, & Other Stone' '09 02 07 Shipping'
#  '04 01 05 Solar' '04 01 99 Unspecified' '04 01 04 Other'
#  '10 02 99 Unspecified' '05 10 11 Electronic Engineering'
#  '16 99 99 Unspecified' '05 10 33 Sustainable Development'
#  '01 10 01 Available For Transfer' '05 13 03 Biochemistry, Bioengineering'
#  "05 10 24 Other 'Production, Technology, Engineering'"
#  '05 10 99 Unspecified' '05 10 12 Energy Technology, Electromagnetism'
#  '05 10 20 Measurement, Control, Precision Engineering'
#  "11 03 07 Fuller's Earth, Kieselguhr, Bentonite & Similar Products"
#  '18 02 04 Glassware' '18 99 99 Unspecified' '10 99 99 Unspecified'
#  "05 06 01 Other 'Law, Legal Matters'" '20 10 01 Polyethylene Polythene'
#  '06 07 99 Unspecified' '06 99 99 Unspecified'
#  '12 15 02 Other Organic Compounds, n.e.s'
#  '11 03 09 Gypsum; Anhydrite; Plasters Inc Plasterboard'
#  '18 01 02 Glass Fibres (Incl. Glass Wool)' '19 03 01 Paper & Cardboard'
#  '06 05 03 Grass Cuttings' '22 05 01 Cardboard' '06 05 99 Unspecified'
#  '06 04 04 Solid Vegetable' '08 99 99 Unspecified' '08 02 07 Other'
#  '20 15 01 Polyvinyl Chloride/ PVC/uPVC/Vinyl'
#  '20 02 01 High Density Polyethylene HDPE' '22 02 02 Good Pallets'
#  '17 10 07 Plant' '09 02 08 Storage & Distribution'
#  '17 08 11 Other appliances for cleaning' '22 02 04 Wood Products'
#  '22 02 01 Broken Pallets' '22 03 03 Mdf' '22 01 01 Sawdust'
#  '22 01 02 Wood Shavings' '01 07 01 Other'
#  '10 03 11 Other Pure Iron, Excluding Steel' '03 99 99 Unspecified'
#  '05 10 15 Food Technology' '22 05 02 Paper' '09 01 09 Transport By Rail'
#  '07 07 01 Calcium Carbonate, (Limestone, Chalk)' '05 11 04 HACCP'
#  '11 03 05 Chalk & Limestone Inc. Oolite' '01 07 99 Unspecified'
#  "05 04 02 Other 'Infrastructure, Environment'" '05 11 99 Unspecified'
#  '05 07 99 Unspecified' '05 11 07 ISO 9001 / Quality Management Systems'
#  '05 12 10 Research, Chemistry, Physical, Optics'
#  '05 10 18 Maintenance Management' '05 05 99 Unspecified'
#  '05 10 04 Biotechnology, Bio (medical) Processes'
#  '05 10 27 Polymers, Plastics, Rubber'
#  "05 02 01 Other 'Construction, Real Estate'"
#  "05 11 19 Other 'Health, Safety'" '11 01 03 Ceramic Fibre'
#  '16 04 02 Other Tools' '01 02 02 Mechanical'
#  '09 02 06 Road Transport, Traffic' '15 01 99 Unspecified'
#  '10 03 03 Copper' '20 12 01 Polypropylene PP' '20 06 01 Other Polyester'
#  '01 03 99 Unspecified' '20 03 01 Low Density Polyethylene LDPE'
#  '01 08 05 Other' '09 99 99 Unspecified' '10 03 07 Magnesium'
#  '06 01 99 Unspecified' '07 18 04 Other Nitrogen Compounds'
#  '10 01 99 Unspecified' '10 02 08 Other Iron Oxide Wastes'
#  '06 01 04 Misc Fish Wastes'
#  '05 08 02 Public Relations, Investor Relations, Press'
#  '17 08 26 Others used for refrigeration, conservation & storage of food'
#  '14 99 99 Unspecified' '20 04 01 Nylon' '12 07 04 Paraffin Waxes'
#  '01 08 01 Outdoor' '17 08 99 Unspecified'
#  '20 08 01 Polyethylene terephthalate PET' '20 13 01 Polystyrene PS'
#  "05 12 06 Other 'Research, Development, Design'" '06 04 99 Unspecified'
#  '20 01 99 Unspecified' '20 05 99 Unspecified' '20 09 01 Polycarbonate'
#  '20 10 99 Unspecified' '20 15 99 Unspecified'
#  '15 05 02 Agricultural Wastewater' '15 02 03 Industrial Site Drainage'
#  '15 05 08 Organic Bio-degradable'
#  '05 12 01 Analytical Laboratory, Consultancy' '14 01 02 Natural Fur'
#  '14 03 99 Unspecified' '21 02 01 Other Rubber' '10 01 13 Stainless Steel'
#  '17 08 02 Other Tools' '06 02 03 Seed Husks'
#  '07 14 02 Filter Cakes & Sludges With Uncertain Composition'
#  '07 23 04 Silicone Compounds' '15 03 02 Industrial Sludge'
#  '06 05 06 Tree Prunings' '11 03 99 Unspecified' '22 03 01 Chipboard'
#  '15 05 01 Acidic' '10 01 11 Other Steels' '07 20 01 Phosphates n.e.s'
#  '05 07 03 Other Logistics Management'
#  '12 15 03 Sugars, Pure; Sugar Ethers & Salts, Etc' '04 04 06 Other'
#  '14 04 01 Carpets And Other Textile Floor Covering'
#  '06 06 02 Malted Grain' '01 02 01 Electrical' '14 04 04 Other'
#  '05 09 04 Employees Courses & Training'
#  '11 03 16 Other Mineral Substances n.e.s' '06 03 03 Peat'
#  '03 04 99 Unspecified' '01 05 03 Rooms Only'
#  '17 08 04 Tools for mowing or other gardening activities'
#  '14 03 08 Other Natural Fibre' '14 03 05 Mixed Fibres'
#  '15 01 05 Sea Water' '07 12 03 Hydrogen' '01 04 06 Other'
#  '12 18 01 Artificial Waxes & Prepared Waxes' '03 01 05 Modified Starches'
#  '12 07 03 Other Hydrocarbons Not Treated As Solvents' '15 05 09 Other'
#  '15 01 04 Rivers, Streams' '07 24 01 Sodium Salts n.e.s'] 236
